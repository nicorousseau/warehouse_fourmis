# %%
import networkx as nx

# %%
G = nx.Graph()
G.add_edge('0,0', '1,0', weight=1)
G.add_edge('1,0', '1,1', weight=1)
G.add_edge('0,0', '0,1', weight=1)
G.add_edge('0,1', '1,1', weight=1)

# %%
G.number_of_edges()
G.adj['0,0']
G.edges(data=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 G.number_of_edges()
# ----> 2 G.adj[1]
#
# File /opt/anaconda3/lib/python3.13/site-packages/networkx/classes/coreviews.py:82, in AdjacencyView.__getitem__(self, name)
#      81 def __getitem__(self, name):
# ---> 82     return AtlasView(self._atlas[name])
#
# KeyError: 1
